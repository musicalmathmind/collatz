# %%
import utils.collatz_construction as cc
import utils.graphing as graphing

graphing.point_size = 3 # generate higher resolution images

# %%
plus_1_option = cc.create_collatz_3x_plus_1_options();
graphing.graph_options(10000, [plus_1_option], ['red'], '3x + 1')

# %%
plus_3_option = cc.create_collatz_3x_plus_3_options();
graphing.graph_options(10000, [plus_3_option], ['blue'], '3x + 3')

# %%
plus_1_option = cc.create_collatz_3x_plus_1_options();
plus_2_option = cc.create_collatz_3x_plus_3_options();
graphing.graph_options(10000, [plus_1_option, plus_2_option], ['red', 'blue'], '3x + 1 vs 3x + 3')
