# %%
import utils.collatz_construction as cc
import utils.graphing as graphing
from utils.orbit_info import OrbitInfo

graphing.POINT_SIZE = 3 # generate higher resolution images
def point_builder(info: OrbitInfo):
    return (info.n, info.get_total_op_count('m3a3'), info.get_total_op_count('m3a1'))

# %%
m3a1_option = cc.create_m3a1_options();
graphing.graph_options(10000, [m3a1_option], point_builder, ['red'], 'n', 'm3a3 count', 'm3a1 count', title='m3a1 Options')

# %%
m3a3_option = cc.create_m3a3_options();
graphing.graph_options(10000, [m3a3_option], point_builder, ['blue'], 'n', 'm3a3 count', 'm3a1 count', title='m3a3 Options')

# %%
probability_option = cc.create_probabilistic_options(.5);
graphing.graph_options(10000, [probability_option], point_builder, ['grean'], 'n', 'm3a3 count', 'm3a1 count', title='Probabalistic Options')

# %%
graphing.graph_options(5000, [m3a1_option, m3a3_option, probability_option],  point_builder, ['red', 'blue', 'green'], title='Comparing All Options')
